# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
columns=[i for i in range(1,12,1)]

feuerkogel=pd.read_excel("../../dat/Qualitätsdatenabfrage_20190826_1426.xlsx",
                         sheet_name="Daten_T",
                         skiprows=[0,1,2],
                         usecols=columns,
                         parse_dates = True,
                         index_col="Probenahme-Beginn TT-MM-JJJJ")

# %%
feuerkogel
# Out:
#                                     site Probenahme-(Ende) TT-MM-JJJJ  \
# Probenahme-Beginn TT-MM-JJJJ
# 1981-01-01                    FEUERKOGEL                   1981-01-31
# 1981-02-01                    FEUERKOGEL                   1981-02-28
# 1981-03-01                    FEUERKOGEL                   1981-03-31
# 1981-04-01                    FEUERKOGEL                   1981-04-30
# 1981-05-01                    FEUERKOGEL                   1981-05-31
# 1981-06-01                    FEUERKOGEL                   1981-06-30
# 1981-07-01                    FEUERKOGEL                   1981-07-31
# 1981-08-01                    FEUERKOGEL                   1981-08-31
# 1981-09-01                    FEUERKOGEL                   1981-09-30
# 1981-10-01                    FEUERKOGEL                   1981-10-31
# 1981-11-01                    FEUERKOGEL                   1981-11-30
# 1981-12-01                    FEUERKOGEL                   1981-12-31
# ...

# %%
feuerkogel["Delta 18O (‰ VSMOW)"].plot()
feuerkogel["Lufttemperatur - Monatsmittel (°C)"].plot()
feuerkogel["Niederschlag - Monatssumme (mm)"].plot()
