# %%
cd ..
# Out:
# /Users/AchilleTalon/Documents/GitHub/ice-in-caves

# %%
import lib.WeatherArchive as arch
import lib.HOBO as hobo

# %%
vogel = arch.read_csv('../dat/vogel_2018_2019.csv','Vogel')
logger_73= hobo.read_csv("../dat/SN 20440473 2019_06_18.csv")
logger_74= hobo.read_csv("../dat/SN 20440474 2019_06_18.csv")
logger_75= hobo.read_csv("../dat/SN 20440475 2019_06_18.csv")

# %%
curves = ((logger_73,logger_75, [vogel,'Vogel']))

# %%
hobo.simpletempPlotter(curves,'Temp, (*C)','2018-09','2019-06-10',filename="../fig/M17_temperature_plot.pdf")
