# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
cd ..
# Out:
# /Users/AchilleTalon/Documents/GitHub/ice-in-caves

# %%
import lib.temp_plotter as tmplt

# %%
VA_2018="../dat/villacher_alpe/1-minuten Daten Villacher Alpe Jahr 2018.xlsx"
VA_2018RR = tmplt.rrReader(VA_2018)

# %%
VA_2019="../dat/villacher_alpe/1-minuten Daten Villacher Alpe Jahr 2019.xlsx"
VA_2019RR = tmplt.rrReader(VA_2019)

# %%
VA_both = pd.concat([VA_2018RR,VA_2019RR])

# %%
VA_2018RR.resample("D").sum().plot()

# %%
#VA_2019RR.resample("D").sum().plot()

# %%
VA_TRF="../dat/villacher_alpe/10-minuten Werte Villacher Alpe.xlsx"
VA_pd = tmplt.TempRFReader(VA_TRF)

# %%
#params1 = {
    #'filename':'villacher_alpe_temp',      ## the exported file name
    #'Title' : 'Villacher Alpe' ,     ## the plot title
    #'plot_dims' : (10,5),        ## needs to be a tuple with two integers
    #'series' : 'TL',    ## this string is the name of series header in a pandas dataframe.
    #'start' :'2018',               ## again a string for start date in yyyy-mm-dd format
    #'end' : '2019-07'}

# %%
#tmplt.tempPlotter(VA_pd,params1)

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax2 = ax.twinx()
ax.plot(VA_pd.TL,linewidth = 0.75)
tmplt.rrPlotter(ax2,VA_both)
plt.show()
